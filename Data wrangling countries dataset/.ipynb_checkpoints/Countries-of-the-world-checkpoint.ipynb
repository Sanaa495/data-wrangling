# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Gathering data

# %%
data= pd.read_csv('countries of the world.csv')
#creating a copy
data_copy=data

# %% [markdown]
# # Data wrangling

# %% [markdown]
# ## Assessing data

# %%
data.sample(5)
# Out:
#            Country                               Region  Population  \
# 225        Zambia   SUB-SAHARAN AFRICA                     11502010
# 23         Bhutan         ASIA (EX. NEAR EAST)              2279723
# 183  Sierra Leone   SUB-SAHARAN AFRICA                      6005250
# 154        Norway   WESTERN EUROPE                          4610820
# 77          Ghana   SUB-SAHARAN AFRICA                     22409572
#
#      Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# 225          752614                       15,3                         0,00
# 23            47000                       48,5                         0,00
# 183           71740                       83,7                         0,56
# 154          323802                       14,2                         7,77
# 77           239460                       93,6                         0,23
#
#     Net migration Infant mortality (per 1000 births)  GDP ($ per capita)  \
# 225             0                              88,29               800.0
# 23              0                             100,44              1300.0
# 183             0                             143,64               500.0
# 154          1,74                                3,7             37800.0
# 77          -0,64                              51,43              2200.0
#
#     Literacy (%) Phones (per 1000) Arable (%) Crops (%) Other (%) Climate  \
# 225         80,6               8,2       7,08      0,03      92,9       2
# 23          42,2              14,3       3,09      0,43     96,48       2
# 183         31,4               4,0       6,98      0,89     92,13       2
# 154        100,0             461,7       2,87         0     97,13       3
# 77          74,8              14,4      16,26      9,67     74,07       2
#
#     Birthrate Deathrate Agriculture Industry Service
# 225        41     19,93        0,22     0,29   0,489
# 23      33,65      12,7       0,258    0,379   0,363
# 183     45,76     23,03        0,49     0,31    0,21
# 154     11,46       9,4       0,021    0,415   0,564
# 77      30,52      9,72       0,366    0,246   0,387

# %%
data_copy=data_copy.rename(columns={'Area (sq. mi.)':'Area', 'Pop. Density (per sq. mi.)': 'Pop_density', 'Coastline (coast/area ratio)': 'Coastline', 'Net migration': 'Migration', 'Infant mortality (per 1000 births)':'Inf_mort','GDP ($ per capita)':'GDP','Literacy (%)':'Literacy','Phones (per 1000)':'Phones','Arable (%)':'Arable','Crops (%)':'Crops', 'Other (%)':'Others'})

# %%
data.shape
# Out:
# (227, 20)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227 entries, 0 to 226
# Data columns (total 20 columns):
# Country                               227 non-null object
# Region                                227 non-null object
# Population                            227 non-null int64
# Area (sq. mi.)                        227 non-null int64
# Pop. Density (per sq. mi.)            227 non-null object
# Coastline (coast/area ratio)          227 non-null object
# Net migration                         224 non-null object
# Infant mortality (per 1000 births)    224 non-null object
# GDP ($ per capita)                    226 non-null float64
# Literacy (%)                          209 non-null object
# Phones (per 1000)                     223 non-null object
# Arable (%)                            225 non-null object
# Crops (%)                             225 non-null object
# Other (%)                             225 non-null object
# Climate                               205 non-null object
# Birthrate                             224 non-null object
# Deathrate                             223 non-null object
# Agriculture                           212 non-null object
# Industry                              211 non-null object
# Service                               212 non-null object
# dtypes: float64(1), int64(2), object(17)
# memory usage: 35.5+ KB

# %%
data.describe()
# Out:
#          Population  Area (sq. mi.)  GDP ($ per capita)
# count  2.270000e+02    2.270000e+02          226.000000
# mean   2.874028e+07    5.982270e+05         9689.823009
# std    1.178913e+08    1.790282e+06        10049.138513
# min    7.026000e+03    2.000000e+00          500.000000
# 25%    4.376240e+05    4.647500e+03         1900.000000
# 50%    4.786994e+06    8.660000e+04         5550.000000
# 75%    1.749777e+07    4.418110e+05        15700.000000
# max    1.313974e+09    1.707520e+07        55100.000000

# %%
data
# Out:
#                    Country                               Region  Population  \
# 0             Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1                 Albania   EASTERN EUROPE                          3581655
# 2                 Algeria   NORTHERN AFRICA                        32930091
# 3          American Samoa   OCEANIA                                   57794
# 4                 Andorra   WESTERN EUROPE                            71201
# 5                  Angola   SUB-SAHARAN AFRICA                     12127071
# 6                Anguilla               LATIN AMER. & CARIB           13477
# 7       Antigua & Barbuda               LATIN AMER. & CARIB           69108
# 8               Argentina               LATIN AMER. & CARIB        39921833
# 9                 Armenia                  C.W. OF IND. STATES      2976372
# 10                  Aruba               LATIN AMER. & CARIB           71891
# 11              Australia   OCEANIA                                20264082
# 12                Austria   WESTERN EUROPE                          8192880
# 13             Azerbaijan                  C.W. OF IND. STATES      7961619
# 14           Bahamas, The               LATIN AMER. & CARIB          303770
# 15                Bahrain   NEAR EAST                                698585
# 16             Bangladesh         ASIA (EX. NEAR EAST)            147365352
# 17               Barbados               LATIN AMER. & CARIB          279912
# 18                Belarus                  C.W. OF IND. STATES     10293011
# 19                Belgium   WESTERN EUROPE                         10379067
# 20                 Belize               LATIN AMER. & CARIB          287730
# 21                  Benin   SUB-SAHARAN AFRICA                      7862944
# 22                Bermuda   NORTHERN AMERICA                          65773
# 23                 Bhutan         ASIA (EX. NEAR EAST)              2279723
# 24                Bolivia               LATIN AMER. & CARIB         8989046
# 25   Bosnia & Herzegovina   EASTERN EUROPE                          4498976
# 26               Botswana   SUB-SAHARAN AFRICA                      1639833
# 27                 Brazil               LATIN AMER. & CARIB       188078227
# 28     British Virgin Is.               LATIN AMER. & CARIB           23098
# 29                 Brunei         ASIA (EX. NEAR EAST)               379444
# ..                     ...                                  ...         ...
# 197                 Syria   NEAR EAST                              18881361
# 198                Taiwan         ASIA (EX. NEAR EAST)             23036087
# 199            Tajikistan                  C.W. OF IND. STATES      7320815
# 200              Tanzania   SUB-SAHARAN AFRICA                     37445392
# 201              Thailand         ASIA (EX. NEAR EAST)             64631595
# 202                  Togo   SUB-SAHARAN AFRICA                      5548702
# 203                 Tonga   OCEANIA                                  114689
# 204     Trinidad & Tobago               LATIN AMER. & CARIB         1065842
# 205               Tunisia   NORTHERN AFRICA                        10175014
# 206                Turkey   NEAR EAST                              70413958
# 207          Turkmenistan                  C.W. OF IND. STATES      5042920
# 208     Turks & Caicos Is               LATIN AMER. & CARIB           21152
# 209                Tuvalu   OCEANIA                                   11810
# 210                Uganda   SUB-SAHARAN AFRICA                     28195754
# 211               Ukraine                  C.W. OF IND. STATES     46710816
# 212  United Arab Emirates   NEAR EAST                               2602713
# 213        United Kingdom   WESTERN EUROPE                         60609153
# 214         United States   NORTHERN AMERICA                      298444215
# 215               Uruguay               LATIN AMER. & CARIB         3431932
# 216            Uzbekistan                  C.W. OF IND. STATES     27307134
# 217               Vanuatu   OCEANIA                                  208869
# 218             Venezuela               LATIN AMER. & CARIB        25730435
# 219               Vietnam         ASIA (EX. NEAR EAST)             84402966
# 220        Virgin Islands               LATIN AMER. & CARIB          108605
# 221     Wallis and Futuna   OCEANIA                                   16025
# 222             West Bank   NEAR EAST                               2460492
# 223        Western Sahara   NORTHERN AFRICA                          273008
# 224                 Yemen   NEAR EAST                              21456188
# 225                Zambia   SUB-SAHARAN AFRICA                     11502010
# 226              Zimbabwe   SUB-SAHARAN AFRICA                     12236805
#
#      Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# 0            647500                       48,0                         0,00
# 1             28748                      124,6                         1,26
# 2           2381740                       13,8                         0,04
# 3               199                      290,4                        58,29
# 4               468                      152,1                         0,00
# 5           1246700                        9,7                         0,13
# 6               102                      132,1                        59,80
# 7               443                      156,0                        34,54
# 8           2766890                       14,4                         0,18
# 9             29800                       99,9                         0,00
# 10              193                      372,5                        35,49
# 11          7686850                        2,6                         0,34
# 12            83870                       97,7                         0,00
# 13            86600                       91,9                         0,00
# 14            13940                       21,8                        25,41
# 15              665                     1050,5                        24,21
# 16           144000                     1023,4                         0,40
# 17              431                      649,5                        22,51
# 18           207600                       49,6                         0,00
# 19            30528                      340,0                         0,22
# 20            22966                       12,5                         1,68
# 21           112620                       69,8                         0,11
# 22               53                     1241,0                       194,34
# 23            47000                       48,5                         0,00
# 24          1098580                        8,2                         0,00
# 25            51129                       88,0                         0,04
# 26           600370                        2,7                         0,00
# 27          8511965                       22,1                         0,09
# 28              153                      151,0                        52,29
# 29             5770                       65,8                         2,79
# ..              ...                        ...                          ...
# 197          185180                      102,0                         0,10
# 198           35980                      640,3                         4,35
# 199          143100                       51,2                         0,00
# 200          945087                       39,6                         0,15
# 201          514000                      125,7                         0,63
# 202           56785                       97,7                         0,10
# 203             748                      153,3                        56,02
# 204            5128                      207,9                         7,06
# 205          163610                       62,2                         0,70
# 206          780580                       90,2                         0,92
# 207          488100                       10,3                         0,00
# 208             430                       49,2                        90,47
# 209              26                      454,2                        92,31
# 210          236040                      119,5                         0,00
# 211          603700                       77,4                         0,46
# 212           82880                       31,4                         1,59
# 213          244820                      247,6                         5,08
# 214         9631420                       31,0                         0,21
# 215          176220                       19,5                         0,37
# 216          447400                       61,0                         0,00
# 217           12200                       17,1                        20,72
# 218          912050                       28,2                         0,31
# 219          329560                      256,1                         1,05
# 220            1910                       56,9                         9,84
# 221             274                       58,5                        47,08
# 222            5860                      419,9                         0,00
# 223          266000                        1,0                         0,42
# 224          527970                       40,6                         0,36
# 225          752614                       15,3                         0,00
# 226          390580                       31,3                         0,00
#
#     Net migration Infant mortality (per 1000 births)  GDP ($ per capita)  \
# 0           23,06                             163,07               700.0
# 1           -4,93                              21,52              4500.0
# 2           -0,39                                 31              6000.0
# 3          -20,71                               9,27              8000.0
# 4             6,6                               4,05             19000.0
# 5               0                             191,19              1900.0
# 6           10,76                              21,03              8600.0
# 7           -6,15                              19,46             11000.0
# 8            0,61                              15,18             11200.0
# 9           -6,47                              23,28              3500.0
# 10              0                               5,89             28000.0
# 11           3,98                               4,69             29000.0
# 12              2                               4,66             30000.0
# 13           -4,9                              81,74              3400.0
# 14           -2,2                              25,21             16700.0
# 15           1,05                              17,27             16900.0
# 16          -0,71                               62,6              1900.0
# 17          -0,31                               12,5             15700.0
# 18           2,54                              13,37              6100.0
# 19           1,23                               4,68             29100.0
# 20              0                              25,69              4900.0
# 21              0                                 85              1100.0
# 22           2,49                               8,53             36000.0
# 23              0                             100,44              1300.0
# 24          -1,32                              53,11              2400.0
# 25           0,31                              21,05              6100.0
# 26              0                              54,58              9000.0
# 27          -0,03                              29,61              7600.0
# 28          10,01                              18,05             16000.0
# 29           3,59                              12,61             18600.0
# ..            ...                                ...                 ...
# 197             0                              29,53              3300.0
# 198             0                                6,4             23400.0
# 199         -2,86                             110,76              1000.0
# 200         -2,06                              98,54               600.0
# 201             0                              20,48              7400.0
# 202             0                              66,61              1500.0
# 203             0                              12,62              2200.0
# 204        -10,83                              24,31              9500.0
# 205         -0,57                              24,77              6900.0
# 206             0                              41,04              6700.0
# 207         -0,86                              73,08              5800.0
# 208         11,68                              15,67              9600.0
# 209             0                              20,03              1100.0
# 210             0                              67,83              1400.0
# 211         -0,39                              20,34              5400.0
# 212          1,03                              14,51             23200.0
# 213          2,19                               5,16             27700.0
# 214          3,41                                6,5             37800.0
# 215         -0,32                              11,95             12800.0
# 216         -1,72                               71,1              1700.0
# 217             0                              55,16              2900.0
# 218         -0,04                               22,2              4800.0
# 219         -0,45                              25,95              2500.0
# 220         -8,94                               8,03             17200.0
# 221           NaN                                NaN              3700.0
# 222          2,98                              19,62               800.0
# 223           NaN                                NaN                 NaN
# 224             0                               61,5               800.0
# 225             0                              88,29               800.0
# 226             0                              67,69              1900.0
#
#     Literacy (%) Phones (per 1000) Arable (%) Crops (%) Other (%) Climate  \
# 0           36,0               3,2      12,13      0,22     87,65       1
# 1           86,5              71,2      21,09      4,42     74,49       3
# 2           70,0              78,1       3,22      0,25     96,53       1
# 3           97,0             259,5         10        15        75       2
# 4          100,0             497,2       2,22         0     97,78       3
# 5           42,0               7,8       2,41      0,24     97,35     NaN
# 6           95,0             460,0          0         0       100       2
# 7           89,0             549,9      18,18      4,55     77,27       2
# 8           97,1             220,4      12,31      0,48     87,21       3
# 9           98,6             195,7      17,55       2,3     80,15       4
# 10          97,0             516,1      10,53         0     89,47       2
# 11         100,0             565,5       6,55      0,04     93,41       1
# 12          98,0             452,2      16,91      0,86     82,23       3
# 13          97,0             137,1      19,63      2,71     77,66       1
# 14          95,6             460,6        0,8       0,4      98,8       2
# 15          89,1             281,3       2,82      5,63     91,55       1
# 16          43,1               7,3      62,11      3,07     34,82       2
# 17          97,4             481,9      37,21      2,33     60,46       2
# 18          99,6             319,1      29,55       0,6     69,85       4
# 19          98,0             462,6      23,28       0,4     76,32       3
# 20          94,1             115,7       2,85      1,71     95,44       2
# 21          40,9               9,7      18,08       2,4     79,52       2
# 22          98,0             851,4         20         0        80       2
# 23          42,2              14,3       3,09      0,43     96,48       2
# 24          87,2              71,9       2,67      0,19     97,14     1,5
# 25           NaN             215,4       13,6      2,96     83,44       4
# 26          79,8              80,5       0,65      0,01     99,34       1
# 27          86,4             225,3       6,96       0,9     92,15       2
# 28          97,8             506,5         20      6,67     73,33       2
# 29          93,9             237,2       0,57      0,76     98,67       2
# ..           ...               ...        ...       ...       ...     ...
# 197         76,9             153,8      25,22      4,43     70,35       1
# 198         96,1             591,0         24         1        75       2
# 199         99,4              33,5       6,61      0,92     92,47       2
# 200         78,2               4,0       4,52      1,08      94,4     NaN
# 201         92,6             108,9      29,36      6,46     64,18       2
# 202         60,9              10,6      46,15      2,21     51,64       2
# 203         98,5              97,7      23,61     43,06     33,33       2
# 204         98,6             303,5      14,62      9,16     76,22       2
# 205         74,2             123,6      17,86     13,74      68,4       3
# 206         86,5             269,5      30,93      3,31     65,76       3
# 207         98,0              74,6       3,72      0,14     96,14       1
# 208         98,0             269,5       2,33         0     97,67       2
# 209          NaN              59,3          0         0       100       2
# 210         69,9               3,6      25,88     10,65     63,47       2
# 211         99,7             259,9      56,21      1,61     42,18       3
# 212         77,9             475,3        0,6      2,25     97,15       1
# 213         99,0             543,5      23,46      0,21     76,33       3
# 214         97,0             898,0      19,13      0,22     80,65       3
# 215         98,0             291,4       7,43      0,23     92,34       3
# 216         99,3              62,9      10,83      0,83     88,34       1
# 217         53,0              32,6       2,46      7,38     90,16       2
# 218         93,4             140,1       2,95      0,92     96,13       2
# 219         90,3             187,7      19,97      5,95     74,08       2
# 220          NaN             652,8      11,76      2,94      85,3       2
# 221         50,0             118,6          5        25        70       2
# 222          NaN             145,2       16,9     18,97     64,13       3
# 223          NaN               NaN       0,02         0     99,98       1
# 224         50,2              37,2       2,78      0,24     96,98       1
# 225         80,6               8,2       7,08      0,03      92,9       2
# 226         90,7              26,8       8,32      0,34     91,34       2
#
#     Birthrate Deathrate Agriculture Industry Service
# 0        46,6     20,34        0,38     0,24    0,38
# 1       15,11      5,22       0,232    0,188   0,579
# 2       17,14      4,61       0,101      0,6   0,298
# 3       22,46      3,27         NaN      NaN     NaN
# 4        8,71      6,25         NaN      NaN     NaN
# 5       45,11      24,2       0,096    0,658   0,246
# 6       14,17      5,34        0,04     0,18    0,78
# 7       16,93      5,37       0,038     0,22   0,743
# 8       16,73      7,55       0,095    0,358   0,547
# 9       12,07      8,23       0,239    0,343   0,418
# 10      11,03      6,68       0,004    0,333   0,663
# 11      12,14      7,51       0,038    0,262     0,7
# 12       8,74      9,76       0,018    0,304   0,678
# 13      20,74      9,75       0,141    0,457   0,402
# 14      17,57      9,05        0,03     0,07     0,9
# 15       17,8      4,14       0,005    0,387   0,608
# 16       29,8      8,27       0,199    0,198   0,603
# 17      12,71      8,67        0,06     0,16    0,78
# 18      11,16     14,02       0,093    0,316   0,591
# 19      10,38     10,27        0,01     0,24   0,749
# 20      28,84      5,72       0,142    0,152   0,612
# 21      38,85     12,22       0,316    0,138   0,546
# 22       11,4      7,74        0,01      0,1    0,89
# 23      33,65      12,7       0,258    0,379   0,363
# 24       23,3      7,53       0,128    0,352    0,52
# 25       8,77      8,27       0,142    0,308    0,55
# 26      23,08      29,5       0,024    0,469   0,507
# 27      16,56      6,17       0,084      0,4   0,516
# 28      14,89      4,42       0,018    0,062    0,92
# 29      18,79      3,45       0,036    0,561   0,403
# ..        ...       ...         ...      ...     ...
# 197     27,76      4,81       0,249     0,23   0,519
# 198     12,56      6,48       0,018    0,259   0,723
# 199     32,65      8,25       0,234    0,286    0,48
# 200     37,71     16,39       0,432    0,172   0,396
# 201     13,87      7,04       0,099    0,441    0,46
# 202     37,01      9,83       0,395    0,204   0,401
# 203     25,37      5,28        0,23     0,27     0,5
# 204      12,9     10,57       0,007     0,57   0,423
# 205     15,52      5,13       0,132    0,318    0,55
# 206     16,62      5,97       0,117    0,298   0,585
# 207     27,61       8,6       0,209     0,38   0,411
# 208     21,84      4,21         NaN      NaN     NaN
# 209     22,18      7,11       0,166    0,272   0,562
# 210     47,35     12,24       0,311    0,222   0,469
# 211      8,82     14,39       0,187    0,452   0,361
# 212     18,96       4,4        0,04    0,585   0,375
# 213     10,71     10,13       0,005    0,237   0,758
# 214     14,14      8,26        0,01    0,204   0,787
# 215     13,91      9,05       0,093    0,311   0,596
# 216     26,36      7,84       0,342    0,229    0,43
# 217     22,72      7,82        0,26     0,12    0,62
# 218     18,71      4,92        0,04    0,419   0,541
# 219     16,86      6,22       0,209     0,41   0,381
# 220     13,96      6,43        0,01     0,19     0,8
# 221       NaN       NaN         NaN      NaN     NaN
# 222     31,67      3,92        0,09     0,28    0,63
# 223       NaN       NaN         NaN      NaN     0,4
# 224     42,89       8,3       0,135    0,472   0,393
# 225        41     19,93        0,22     0,29   0,489
# 226     28,01     21,84       0,179    0,243   0,579
#
# [227 rows x 20 columns]

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.isnull().sum()
# Out:
# Country                                0
# Region                                 0
# Population                             0
# Area (sq. mi.)                         0
# Pop. Density (per sq. mi.)             0
# Coastline (coast/area ratio)           0
# Net migration                          3
# Infant mortality (per 1000 births)     3
# GDP ($ per capita)                     1
# Literacy (%)                          18
# Phones (per 1000)                      4
# Arable (%)                             2
# Crops (%)                              2
# Other (%)                              2
# Climate                               22
# Birthrate                              3
# Deathrate                              4
# Agriculture                           15
# Industry                              16
# Service                               15
# dtype: int64

# %% [markdown]
# ### Issues
#
# #### Quality-
#
# - Inaccurate way to store decimal numbers (use of commas instead of decimal points) (Validity)
# - Inaccurate datatypes for number values (Validity)

# %% [markdown]
# #### Define: Inaccurate way to store decimal numbers (use of commas instead of decimal points) (Validity)
# Solution: Replace all commas with dots in the required columns

# %% [markdown]
# #### Code

# %%
def proper_decimal(a):
    new=[]
    for i in a:
        new.append(str(i).replace(',','.'))
    return new
data_copy['Pop_density']=proper_decimal(data_copy['Pop_density'])
data_copy['Coastline']=proper_decimal(data_copy['Coastline'])
data_copy['Migration']=proper_decimal(data_copy['Migration'])
data_copy['Inf_mort']=proper_decimal(data_copy['Inf_mort'])
data_copy['Literacy']=proper_decimal(data_copy['Literacy'])
data_copy['Phones']=proper_decimal(data_copy['Phones'])
data_copy['Arable']=proper_decimal(data_copy['Arable'])
data_copy['Crops']=proper_decimal(data_copy['Crops'])
data_copy['Others']=proper_decimal(data_copy['Others'])
data_copy['Climate']=proper_decimal(data_copy['Climate'])
data_copy['Birthrate']=proper_decimal(data_copy['Birthrate'])
data_copy['Deathrate']=proper_decimal(data_copy['Deathrate'])
data_copy['Agriculture']=proper_decimal(data_copy['Agriculture'])
data_copy['Industry']=proper_decimal(data_copy['Industry'])
data_copy['Service']=proper_decimal(data_copy['Service'])

# %%
data_copy=data_copy.astype({'Pop_density':float,'Coastline':float,'Migration':float,'Inf_mort':float,'Literacy':float,'Phones':float,'Arable':float,'Crops':float,'Others':float,'Climate':float,'Birthrate':float,'Deathrate':float,'Agriculture':float,'Industry':float,'Service':float})
#first converted climate to float type to get numerical NaN values instead of string NaN values; then converting it into a category
data_copy=data_copy.astype({'Climate':'category', 'Country':'category', 'Region':'category'})

# %% [markdown]
# #### Test

# %%
data_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227 entries, 0 to 226
# Data columns (total 20 columns):
# Country        227 non-null category
# Region         227 non-null category
# Population     227 non-null int64
# Area           227 non-null int64
# Pop_density    227 non-null float64
# Coastline      227 non-null float64
# Migration      224 non-null float64
# Inf_mort       224 non-null float64
# GDP            226 non-null float64
# Literacy       209 non-null float64
# Phones         223 non-null float64
# Arable         225 non-null float64
# Crops          225 non-null float64
# Others         225 non-null float64
# Climate        205 non-null category
# Birthrate      224 non-null float64
# Deathrate      223 non-null float64
# Agriculture    212 non-null float64
# Industry       211 non-null float64
# Service        212 non-null float64
# dtypes: category(3), float64(15), int64(2)
# memory usage: 43.5 KB

# %% [markdown]
# # Re-assessing

# %%
data_copy.describe()
# Out:
#          Population          Area   Pop_density   Coastline   Migration  \
# count  2.270000e+02  2.270000e+02    227.000000  227.000000  224.000000
# mean   2.874028e+07  5.982270e+05    379.047137   21.165330    0.038125
# std    1.178913e+08  1.790282e+06   1660.185825   72.286863    4.889269
# min    7.026000e+03  2.000000e+00      0.000000    0.000000  -20.990000
# 25%    4.376240e+05  4.647500e+03     29.150000    0.100000   -0.927500
# 50%    4.786994e+06  8.660000e+04     78.800000    0.730000    0.000000
# 75%    1.749777e+07  4.418110e+05    190.150000   10.345000    0.997500
# max    1.313974e+09  1.707520e+07  16271.500000  870.660000   23.060000
#
#          Inf_mort           GDP    Literacy       Phones      Arable  \
# count  224.000000    226.000000  209.000000   223.000000  225.000000
# mean    35.506964   9689.823009   82.838278   236.061435   13.797111
# std     35.389899  10049.138513   19.722173   227.991829   13.040402
# min      2.290000    500.000000   17.600000     0.200000    0.000000
# 25%      8.150000   1900.000000   70.600000    37.800000    3.220000
# 50%     21.000000   5550.000000   92.500000   176.200000   10.420000
# 75%     55.705000  15700.000000   98.000000   389.650000   20.000000
# max    191.190000  55100.000000  100.000000  1035.600000   62.110000
#
#             Crops      Others   Birthrate   Deathrate  Agriculture  \
# count  225.000000  225.000000  224.000000  223.000000   212.000000
# mean     4.564222   81.638311   22.114732    9.241345     0.150844
# std      8.361470   16.140835   11.176716    4.990026     0.146798
# min      0.000000   33.330000    7.290000    2.290000     0.000000
# 25%      0.190000   71.650000   12.672500    5.910000     0.037750
# 50%      1.030000   85.700000   18.790000    7.840000     0.099000
# 75%      4.440000   95.440000   29.820000   10.605000     0.221000
# max     50.680000  100.000000   50.730000   29.740000     0.769000
#
#          Industry     Service
# count  211.000000  212.000000
# mean     0.282711    0.565283
# std      0.138272    0.165841
# min      0.020000    0.062000
# 25%      0.193000    0.429250
# 50%      0.272000    0.571000
# 75%      0.341000    0.678500
# max      0.906000    0.954000

# %%
data_copy.sample(5)
# Out:
#           Country                               Region  Population    Area  \
# 196  Switzerland   WESTERN EUROPE                          7523934   41290
# 26      Botswana   SUB-SAHARAN AFRICA                      1639833  600370
# 201     Thailand         ASIA (EX. NEAR EAST)             64631595  514000
# 63       Eritrea   SUB-SAHARAN AFRICA                      4786994  121320
# 123    Macedonia   EASTERN EUROPE                          2050554   25333
#
#      Pop_density  Coastline  Migration  Inf_mort      GDP  Literacy  Phones  \
# 196        182.2       0.00       4.05      4.39  32700.0      99.0   680.9
# 26           2.7       0.00       0.00     54.58   9000.0      79.8    80.5
# 201        125.7       0.63       0.00     20.48   7400.0      92.6   108.9
# 63          39.5       1.84       0.00     74.87    700.0      58.6     7.9
# 123         80.9       0.00      -1.45     10.09   6700.0       NaN   260.0
#
#      Arable  Crops  Others Climate  Birthrate  Deathrate  Agriculture  \
# 196   10.42   0.61   88.97     3.0       9.71       8.49        0.015
# 26     0.65   0.01   99.34     1.0      23.08      29.50        0.024
# 201   29.36   6.46   64.18     2.0      13.87       7.04        0.099
# 63     4.95   0.03   95.02     1.5      34.33       9.60        0.102
# 123   22.26   1.81   75.93     3.0      12.02       8.77        0.118
#
#      Industry  Service
# 196     0.340    0.645
# 26      0.469    0.507
# 201     0.441    0.460
# 63      0.254    0.643
# 123     0.319    0.563

# %% [markdown]
# ### Issues
#
# #### Quality-
#
# - Population density has low accuracy (minimum is 0) (Accuracy)
# - Region column has all capitals (Consistency)

# %% [markdown]
# #### Define: Population density has low accuracy (minimum is 0) (Accuracy)
# Solution: Calculate Population density using the formula Total opulation/Area in square km

# %% [markdown]
# #### Code

# %%
data_copy['Pop_density']=data_copy['Population']/data_copy['Area']

# %% [markdown]
# #### Test

# %%
data_copy['Pop_density'].describe()
# Out:
# count      227.000000
# mean       379.042510
# std       1660.187317
# min          0.026020
# 25%         29.157808
# 50%         78.772786
# 75%        190.106186
# max      16271.500000
# Name: Pop_density, dtype: float64

# %% [markdown]
# #### Define: Region column has all capitals

# %% [markdown]
# #### Code

# %%
reg=[]
for i in data_copy['Region']:
    reg.append(i.title().strip())
data_copy['Region']=reg
data_copy=data_copy.astype({'Region':'category'})

# %% [markdown]
# #### Test

# %%
data_copy['Region'].sample(5)
# Out:
# 171     Sub-Saharan Africa
# 66          Western Europe
# 212              Near East
# 183     Sub-Saharan Africa
# 169    C.W. Of Ind. States
# Name: Region, dtype: category
# Categories (11, object): [Asia (Ex. Near East), Baltics, C.W. Of Ind. States, Eastern Europe, ..., Northern America, Oceania, Sub-Saharan Africa, Western Europe]

# %%
data_copy.dtypes
# Out:
# Country        category
# Region         category
# Population        int64
# Area              int64
# Pop_density     float64
# Coastline       float64
# Migration       float64
# Inf_mort        float64
# GDP             float64
# Literacy        float64
# Phones          float64
# Arable          float64
# Crops           float64
# Others          float64
# Climate        category
# Birthrate       float64
# Deathrate       float64
# Agriculture     float64
# Industry        float64
# Service         float64
# dtype: object

# %% [markdown]
# # Univariate analysis

# %%
def pdfcdf(x,bins):
    counts, edges=np.histogram(x, bins=bins)
    pdf=counts/sum(counts)
    cdf=np.cumsum(pdf)
    plt.plot(edges[1:],pdf, label='Probabilty Density Function')
    plt.plot(edges[1:],cdf, label='Cumilative Density Function')
    plt.title('Probability and Cumulative density graphs')
    plt.legend(loc="right")

# %%
for i in data_copy.columns[1:]:
    if str(data_copy[i].dtype)== 'category':
#         sns.distplot(data_copy[i].dropna())
#         print(i)
        f,ax = plt.subplots(figsize =(20,10))
        sns.countplot(data_copy[i], ax=ax)
        plt.show()
        data_copy[i].value_counts().plot(kind='pie', autopct='%0.2f')
        plt.show()
#         pdfcdf(data_copy[i],len(data_copy[i].unique()))
#         plt.show()
    else:
        sns.distplot(data_copy[i].dropna(), rug=True)
        plt.show()
        pdfcdf(data_copy[i].dropna(),int(data_copy[i].max()/10)+1)
        plt.show()
        sns.boxplot(data_copy[i].dropna())
        plt.show()
        sns.distplot(data_copy[data_copy[i]<data_copy[i].quantile(0.90)][i],rug=True, label='Plot for 90% nations', color='orange')
        plt.legend()
        plt.show()
# Out:
# /Users/ritwikghosh/anaconda/lib/python3.5/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# /Users/ritwikghosh/anaconda/lib/python3.5/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# # Multivariate analysis

# %% [markdown]
# ## Climate influence

# %%
ct=pd.crosstab(data_copy['Climate'],data_copy['Country'])
ct
# Out:
# Country  Afghanistan   Albania   Algeria   American Samoa   Andorra   \
# Climate
# 1.0                 1         0         1                0         0
# 1.5                 0         0         0                0         0
# 2.0                 0         0         0                1         0
# 2.5                 0         0         0                0         0
# 3.0                 0         1         0                0         1
# 4.0                 0         0         0                0         0
#
# Country  Anguilla   Antigua & Barbuda   Argentina   Armenia   Aruba   \
# Climate
# 1.0              0                   0           0         0       0
# 1.5              0                   0           0         0       0
# 2.0              1                   1           0         0       1
# 2.5              0                   0           0         0       0
# 3.0              0                   0           1         0       0
# 4.0              0                   0           0         1       0
#
# Country    ...      Vanuatu   Venezuela   Vietnam   Virgin Islands   \
# Climate    ...
# 1.0        ...             0           0         0                0
# 1.5        ...             0           0         0                0
# 2.0        ...             1           1         1                1
# 2.5        ...             0           0         0                0
# 3.0        ...             0           0         0                0
# 4.0        ...             0           0         0                0
#
# Country  Wallis and Futuna   West Bank   Western Sahara   Yemen   Zambia   \
# Climate
# 1.0                       0           0                1       1        0
# 1.5                       0           0                0       0        0
# 2.0                       1           0                0       0        1
# 2.5                       0           0                0       0        0
# 3.0                       0           1                0       0        0
# 4.0                       0           0                0       0        0
#
# Country  Zimbabwe
# Climate
# 1.0              0
# 1.5              0
# 2.0              1
# 2.5              0
# 3.0              0
# 4.0              0
#
# [6 rows x 205 columns]

# %%
ct=pd.crosstab(data_copy['Climate'],data_copy['Region'])
ct
# Out:
# Region   Asia (Ex. Near East)  Baltics  C.W. Of Ind. States  Eastern Europe  \
# Climate
# 1.0                         4        0                    3               0
# 1.5                         1        0                    0               0
# 2.0                        18        0                    1               0
# 2.5                         1        0                    1               0
# 3.0                         3        2                    2               8
# 4.0                         0        0                    3               1
#
# Region   Latin Amer. & Carib  Near East  Northern Africa  Northern America  \
# Climate
# 1.0                        0         10                3                 1
# 1.5                        3          0                0                 0
# 2.0                       39          0                0                 1
# 2.5                        0          0                0                 0
# 3.0                        3          5                1                 1
# 4.0                        0          0                0                 0
#
# Region   Oceania  Sub-Saharan Africa  Western Europe
# Climate
# 1.0            1                   7               0
# 1.5            0                   4               0
# 2.0           19                  33               0
# 2.5            0                   1               0
# 3.0            1                   3              19
# 4.0            0                   0               2

# %%
# plt.figure(figsize=(20,10))
ct.plot(kind='bar',figsize=(20,10))

# %%
sns.heatmap(ct, linewidth=1, annot=True)

# %% [markdown]
# # Geographical properties and their influences

# %%
sns.catplot(x='Climate',y='Agriculture', data=data_copy.dropna(), kind='swarm', hue='Region')

# %% [markdown]
# ### Conclusion:
# 1. Climate 1.0 has a good yeild in general. Small but multiple agricultural endeavours in Latin America and Caribbean region, higher yeilds in Sub-Saharan Africa and Western europe but small in number.
# 2. Climate 1.5 is not very common a climate for agriculture and is mainly practiced in sub-saharan regions.
# 3. CLimate 2.0 is the most common climate for agriculture, with lower numbers in Latin America and very high numbers in sub-saharn region.
# 4. CLimate 2.5 is the rarest climate to practice agriculture in.
# 5. Climate 3.0 is the second-best climate supportive of agriculture, with multiple but low numbers in Western Europe.
# 6. Climate 4.0 is not very supportive of agriculture.

# %%
sns.catplot(x='Climate',y='Arable', data=data_copy.dropna(), kind='swarm', hue='Region')

# %%
sns.catplot(x='Climate',y='Crops', data=data_copy.dropna(), kind='swarm', hue='Region')

# %% [markdown]
# ## Conclusion: we can see there is clearly a trend of climate having an influence on agriculture, land usability and crop yeilds

# %%
sns.catplot(x='Climate',y='Others', data=data_copy.dropna(), kind='swarm', hue='Region')

# %% [markdown]
# ## Conclusion: Conversely, there is clearly an inverse relation between climate and good agricultural yeilds and other modes of income. The more the crop yeild, the lesser the reliance on other modes of income.

# %%
sns.catplot(x='Climate',y='Coastline', data=data_copy.dropna(), kind='swarm', hue='Region')

# %% [markdown]
# #### Conclusion: no particular influence in climate because of coastline

# %% [markdown]
# # Regions and  People patterns

# %%
sns.relplot(x='Population',y='GDP', data=data_copy.dropna(), hue='Region')

# %% [markdown]
# ### Conclusion: Lower population has higher GDP in general. Also, Western european and North American countries are the richest countries

# %%
sns.relplot(x='Pop_density',y='GDP', data=data_copy.dropna(), hue='Region')

# %% [markdown]
# For 60% of the countries to eliminate outliers

# %%
i
# Out:
# 'Service'

# %%
sns.relplot(x='Pop_density',y='GDP', data=data_copy[data_copy['GDP']<data_copy['GDP'].quantile(0.60)].dropna(), hue='Region')

# %% [markdown]
# ### Conclusion: lower population density results in higher GDP. Also, highest population density is found in asian countries, and lowest GDP is found in sub-saharan countries

# %%
sns.relplot(x='Coastline',y='Industry', data=data_copy.dropna(), hue='Region')

# %%
sns.relplot(x='Area',y='Industry', data=data_copy.dropna(), hue='Region')

# %% [markdown]
# ### Conclusion: We can see industries are independent of coastlines in present times, which shows that historical trends have changed when coastline used to play a huge role in transportation of industry materials. Industries also do not have an affinity for larger areas and can thrive in small areas as well.

# %%
sns.relplot(x='Population',y='Industry', data=data_copy.dropna(), hue='Region')

# %%
sns.relplot(x='Pop_density',y='Industry', data=data_copy.dropna(), hue='Region')

# %% [markdown]
# ### Conclusion:  Industry also shows no pattern with population or population density, showing that low labour industires are available as well.

# %%
sns.relplot(x='Pop_density',y='Inf_mort', data=data_copy.dropna(), hue='Region')

# %%
sns.relplot(x='Population',y='Inf_mort', data=data_copy.dropna(), hue='Region')

# %% [markdown]
# ### Conclusion: No relevance of population or population density with infant mortality. Sub saharan countries have highest infant mortality

# %%
sns.jointplot(x='Literacy',y='Phones', data=data_copy.dropna(), color='green')
# Out:
# /Users/ritwikghosh/anaconda/lib/python3.5/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ### Conclusion: There is a positive correlation between literacy and phones used, showing that literate populations use more phones

# %%
sns.jointplot(x='Population',y='Migration', data=data_copy.dropna())
# Out:
# /Users/ritwikghosh/anaconda/lib/python3.5/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.jointplot(x='Pop_density',y='Migration', data=data_copy.dropna(), color='blue')
# Out:
# /Users/ritwikghosh/anaconda/lib/python3.5/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ### Conclusion: No relavance of migration wrt population trends

# %%
sns.relplot(x='GDP',y='Migration', data=data_copy.dropna(), hue='Region')

# %% [markdown]
# ### Conclusion: There is a slight positive correlation, showing people prefet to move from lower income regions to higher income regions. People prefer migrating from latin american countries the most and to Western European, North America and Oceania regions

# %%
sns.relplot(x='GDP',y='Birthrate', data=data_copy.dropna(), hue='Region')

# %%
sns.relplot(x='GDP',y='Deathrate', data=data_copy.dropna(), hue='Region')

# %% [markdown]
# ### Conclusion: A lower GDP shows both high birth and death rates. A higher GDP shows low birth and death rates, showing stable and secure lifestyles. Sub-Saharan countries have the highest Birth and Death rates.

# %%
sns.relplot(x='GDP',y='Literacy', data=data_copy.dropna(), hue='Region')

# %% [markdown]
# ### Conclusion: There is clear positive correlation of literacy rates and GDP. A minimum GDP supports positive and higher literacy rates, but after a certain point the curve flattens as countries with average GDP and high GDP share similar literacy rates

# %% [markdown]
# # Occupation influences

# %%
sns.relplot(x='Population',y='Literacy', data=data_copy.dropna(), hue='Region')

# %% [markdown]
# #### Conclusion: Independent

# %%
sns.relplot(x='Agriculture',y='Literacy', data=data_copy.dropna(), hue='Region')

# %%
sns.relplot(x='Others',y='Literacy', data=data_copy.dropna(), hue='Region')

# %%
sns.relplot(x='Industry',y='Literacy', data=data_copy.dropna(), hue='Region')

# %%
sns.relplot(x='Service',y='Literacy', data=data_copy.dropna(), hue='Region')

# %% [markdown]
# ### Conclusion: Clear negative correlation of literacy with agriculture, and positive correlation with 'Others' occupation and countries with good industries, relating agriculture as an occupation among low literacy populations and other occupations with higher literacy. Industries also have an affinity towards higher loteracy rate. On the other hand, services is not affected much by literacy rates

# %%
sns.jointplot(x='Industry',y='GDP', data=data_copy.dropna(), color='red')
# Out:
# /Users/ritwikghosh/anaconda/lib/python3.5/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ### Conclusion: Lower GDP means lower number of industries. Yet, a high GDP does not necessarily mean a high number of industries as a country may have different sources of income

# %%
sns.jointplot(x='Service',y='GDP', data=data_copy.dropna(), color='green')
# Out:
# /Users/ritwikghosh/anaconda/lib/python3.5/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ## Conclusion: A low GDP means a low number of services available, however a high GDP shows a higher number of services. There is a clear positive correlation.

# %%
sns.jointplot(x='Agriculture',y='GDP', data=data_copy.dropna(), color='orange')
# Out:
# /Users/ritwikghosh/anaconda/lib/python3.5/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ### Conclusion: There is a negative correlation with agriculture and GDP, showing that poorer countries resort to agriculture more

# %%
sns.jointplot(x='Others',y='GDP', data=data_copy.dropna(), color='purple')
# Out:
# /Users/ritwikghosh/anaconda/lib/python3.5/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ### Conclusion: There is positive correlation between GDP and Other modes of occupation (other than agriculture)

# %%
data_copy
# Out:
#                    Country                Region  Population     Area  \
# 0             Afghanistan   Asia (Ex. Near East)    31056997   647500
# 1                 Albania         Eastern Europe     3581655    28748
# 2                 Algeria        Northern Africa    32930091  2381740
# 3          American Samoa                Oceania       57794      199
# 4                 Andorra         Western Europe       71201      468
# 5                  Angola     Sub-Saharan Africa    12127071  1246700
# 6                Anguilla    Latin Amer. & Carib       13477      102
# 7       Antigua & Barbuda    Latin Amer. & Carib       69108      443
# 8               Argentina    Latin Amer. & Carib    39921833  2766890
# 9                 Armenia    C.W. Of Ind. States     2976372    29800
# 10                  Aruba    Latin Amer. & Carib       71891      193
# 11              Australia                Oceania    20264082  7686850
# 12                Austria         Western Europe     8192880    83870
# 13             Azerbaijan    C.W. Of Ind. States     7961619    86600
# 14           Bahamas, The    Latin Amer. & Carib      303770    13940
# 15                Bahrain              Near East      698585      665
# 16             Bangladesh   Asia (Ex. Near East)   147365352   144000
# 17               Barbados    Latin Amer. & Carib      279912      431
# 18                Belarus    C.W. Of Ind. States    10293011   207600
# 19                Belgium         Western Europe    10379067    30528
# 20                 Belize    Latin Amer. & Carib      287730    22966
# 21                  Benin     Sub-Saharan Africa     7862944   112620
# 22                Bermuda       Northern America       65773       53
# 23                 Bhutan   Asia (Ex. Near East)     2279723    47000
# 24                Bolivia    Latin Amer. & Carib     8989046  1098580
# 25   Bosnia & Herzegovina         Eastern Europe     4498976    51129
# 26               Botswana     Sub-Saharan Africa     1639833   600370
# 27                 Brazil    Latin Amer. & Carib   188078227  8511965
# 28     British Virgin Is.    Latin Amer. & Carib       23098      153
# 29                 Brunei   Asia (Ex. Near East)      379444     5770
# ..                     ...                   ...         ...      ...
# 197                 Syria              Near East    18881361   185180
# 198                Taiwan   Asia (Ex. Near East)    23036087    35980
# 199            Tajikistan    C.W. Of Ind. States     7320815   143100
# 200              Tanzania     Sub-Saharan Africa    37445392   945087
# 201              Thailand   Asia (Ex. Near East)    64631595   514000
# 202                  Togo     Sub-Saharan Africa     5548702    56785
# 203                 Tonga                Oceania      114689      748
# 204     Trinidad & Tobago    Latin Amer. & Carib     1065842     5128
# 205               Tunisia        Northern Africa    10175014   163610
# 206                Turkey              Near East    70413958   780580
# 207          Turkmenistan    C.W. Of Ind. States     5042920   488100
# 208     Turks & Caicos Is    Latin Amer. & Carib       21152      430
# 209                Tuvalu                Oceania       11810       26
# 210                Uganda     Sub-Saharan Africa    28195754   236040
# 211               Ukraine    C.W. Of Ind. States    46710816   603700
# 212  United Arab Emirates              Near East     2602713    82880
# 213        United Kingdom         Western Europe    60609153   244820
# 214         United States       Northern America   298444215  9631420
# 215               Uruguay    Latin Amer. & Carib     3431932   176220
# 216            Uzbekistan    C.W. Of Ind. States    27307134   447400
# 217               Vanuatu                Oceania      208869    12200
# 218             Venezuela    Latin Amer. & Carib    25730435   912050
# 219               Vietnam   Asia (Ex. Near East)    84402966   329560
# 220        Virgin Islands    Latin Amer. & Carib      108605     1910
# 221     Wallis and Futuna                Oceania       16025      274
# 222             West Bank              Near East     2460492     5860
# 223        Western Sahara        Northern Africa      273008   266000
# 224                 Yemen              Near East    21456188   527970
# 225                Zambia     Sub-Saharan Africa    11502010   752614
# 226              Zimbabwe     Sub-Saharan Africa    12236805   390580
#
#      Pop_density  Coastline  Migration  Inf_mort      GDP  Literacy  Phones  \
# 0      47.964474       0.00      23.06    163.07    700.0      36.0     3.2
# 1     124.587971       1.26      -4.93     21.52   4500.0      86.5    71.2
# 2      13.826065       0.04      -0.39     31.00   6000.0      70.0    78.1
# 3     290.422111      58.29     -20.71      9.27   8000.0      97.0   259.5
# 4     152.138889       0.00       6.60      4.05  19000.0     100.0   497.2
# 5       9.727337       0.13       0.00    191.19   1900.0      42.0     7.8
# 6     132.127451      59.80      10.76     21.03   8600.0      95.0   460.0
# 7     156.000000      34.54      -6.15     19.46  11000.0      89.0   549.9
# 8      14.428413       0.18       0.61     15.18  11200.0      97.1   220.4
# 9      99.878255       0.00      -6.47     23.28   3500.0      98.6   195.7
# 10    372.492228      35.49       0.00      5.89  28000.0      97.0   516.1
# 11      2.636201       0.34       3.98      4.69  29000.0     100.0   565.5
# 12     97.685466       0.00       2.00      4.66  30000.0      98.0   452.2
# 13     91.935554       0.00      -4.90     81.74   3400.0      97.0   137.1
# 14     21.791248      25.41      -2.20     25.21  16700.0      95.6   460.6
# 15   1050.503759      24.21       1.05     17.27  16900.0      89.1   281.3
# 16   1023.370500       0.40      -0.71     62.60   1900.0      43.1     7.3
# 17    649.447796      22.51      -0.31     12.50  15700.0      97.4   481.9
# 18     49.580978       0.00       2.54     13.37   6100.0      99.6   319.1
# 19    339.985161       0.22       1.23      4.68  29100.0      98.0   462.6
# 20     12.528520       1.68       0.00     25.69   4900.0      94.1   115.7
# 21     69.818363       0.11       0.00     85.00   1100.0      40.9     9.7
# 22   1241.000000     194.34       2.49      8.53  36000.0      98.0   851.4
# 23     48.504745       0.00       0.00    100.44   1300.0      42.2    14.3
# 24      8.182423       0.00      -1.32     53.11   2400.0      87.2    71.9
# 25     87.992646       0.04       0.31     21.05   6100.0       NaN   215.4
# 26      2.731371       0.00       0.00     54.58   9000.0      79.8    80.5
# 27     22.095747       0.09      -0.03     29.61   7600.0      86.4   225.3
# 28    150.967320      52.29      10.01     18.05  16000.0      97.8   506.5
# 29     65.761525       2.79       3.59     12.61  18600.0      93.9   237.2
# ..           ...        ...        ...       ...      ...       ...     ...
# 197   101.962204       0.10       0.00     29.53   3300.0      76.9   153.8
# 198   640.246998       4.35       0.00      6.40  23400.0      96.1   591.0
# 199    51.158735       0.00      -2.86    110.76   1000.0      99.4    33.5
# 200    39.621106       0.15      -2.06     98.54    600.0      78.2     4.0
# 201   125.742403       0.63       0.00     20.48   7400.0      92.6   108.9
# 202    97.714220       0.10       0.00     66.61   1500.0      60.9    10.6
# 203   153.327540      56.02       0.00     12.62   2200.0      98.5    97.7
# 204   207.847504       7.06     -10.83     24.31   9500.0      98.6   303.5
# 205    62.190661       0.70      -0.57     24.77   6900.0      74.2   123.6
# 206    90.207228       0.92       0.00     41.04   6700.0      86.5   269.5
# 207    10.331735       0.00      -0.86     73.08   5800.0      98.0    74.6
# 208    49.190698      90.47      11.68     15.67   9600.0      98.0   269.5
# 209   454.230769      92.31       0.00     20.03   1100.0       NaN    59.3
# 210   119.453288       0.00       0.00     67.83   1400.0      69.9     3.6
# 211    77.374219       0.46      -0.39     20.34   5400.0      99.7   259.9
# 212    31.403390       1.59       1.03     14.51  23200.0      77.9   475.3
# 213   247.566183       5.08       2.19      5.16  27700.0      99.0   543.5
# 214    30.986523       0.21       3.41      6.50  37800.0      97.0   898.0
# 215    19.475270       0.37      -0.32     11.95  12800.0      98.0   291.4
# 216    61.035168       0.00      -1.72     71.10   1700.0      99.3    62.9
# 217    17.120410      20.72       0.00     55.16   2900.0      53.0    32.6
# 218    28.211650       0.31      -0.04     22.20   4800.0      93.4   140.1
# 219   256.108041       1.05      -0.45     25.95   2500.0      90.3   187.7
# 220    56.861257       9.84      -8.94      8.03  17200.0       NaN   652.8
# 221    58.485401      47.08        NaN       NaN   3700.0      50.0   118.6
# 222   419.879181       0.00       2.98     19.62    800.0       NaN   145.2
# 223     1.026346       0.42        NaN       NaN      NaN       NaN     NaN
# 224    40.639029       0.36       0.00     61.50    800.0      50.2    37.2
# 225    15.282748       0.00       0.00     88.29    800.0      80.6     8.2
# 226    31.329830       0.00       0.00     67.69   1900.0      90.7    26.8
#
#      Arable  Crops  Others Climate  Birthrate  Deathrate  Agriculture  \
# 0     12.13   0.22   87.65     1.0      46.60      20.34        0.380
# 1     21.09   4.42   74.49     3.0      15.11       5.22        0.232
# 2      3.22   0.25   96.53     1.0      17.14       4.61        0.101
# 3     10.00  15.00   75.00     2.0      22.46       3.27          NaN
# 4      2.22   0.00   97.78     3.0       8.71       6.25          NaN
# 5      2.41   0.24   97.35     NaN      45.11      24.20        0.096
# 6      0.00   0.00  100.00     2.0      14.17       5.34        0.040
# 7     18.18   4.55   77.27     2.0      16.93       5.37        0.038
# 8     12.31   0.48   87.21     3.0      16.73       7.55        0.095
# 9     17.55   2.30   80.15     4.0      12.07       8.23        0.239
# 10    10.53   0.00   89.47     2.0      11.03       6.68        0.004
# 11     6.55   0.04   93.41     1.0      12.14       7.51        0.038
# 12    16.91   0.86   82.23     3.0       8.74       9.76        0.018
# 13    19.63   2.71   77.66     1.0      20.74       9.75        0.141
# 14     0.80   0.40   98.80     2.0      17.57       9.05        0.030
# 15     2.82   5.63   91.55     1.0      17.80       4.14        0.005
# 16    62.11   3.07   34.82     2.0      29.80       8.27        0.199
# 17    37.21   2.33   60.46     2.0      12.71       8.67        0.060
# 18    29.55   0.60   69.85     4.0      11.16      14.02        0.093
# 19    23.28   0.40   76.32     3.0      10.38      10.27        0.010
# 20     2.85   1.71   95.44     2.0      28.84       5.72        0.142
# 21    18.08   2.40   79.52     2.0      38.85      12.22        0.316
# 22    20.00   0.00   80.00     2.0      11.40       7.74        0.010
# 23     3.09   0.43   96.48     2.0      33.65      12.70        0.258
# 24     2.67   0.19   97.14     1.5      23.30       7.53        0.128
# 25    13.60   2.96   83.44     4.0       8.77       8.27        0.142
# 26     0.65   0.01   99.34     1.0      23.08      29.50        0.024
# 27     6.96   0.90   92.15     2.0      16.56       6.17        0.084
# 28    20.00   6.67   73.33     2.0      14.89       4.42        0.018
# 29     0.57   0.76   98.67     2.0      18.79       3.45        0.036
# ..      ...    ...     ...     ...        ...        ...          ...
# 197   25.22   4.43   70.35     1.0      27.76       4.81        0.249
# 198   24.00   1.00   75.00     2.0      12.56       6.48        0.018
# 199    6.61   0.92   92.47     2.0      32.65       8.25        0.234
# 200    4.52   1.08   94.40     NaN      37.71      16.39        0.432
# 201   29.36   6.46   64.18     2.0      13.87       7.04        0.099
# 202   46.15   2.21   51.64     2.0      37.01       9.83        0.395
# 203   23.61  43.06   33.33     2.0      25.37       5.28        0.230
# 204   14.62   9.16   76.22     2.0      12.90      10.57        0.007
# 205   17.86  13.74   68.40     3.0      15.52       5.13        0.132
# 206   30.93   3.31   65.76     3.0      16.62       5.97        0.117
# 207    3.72   0.14   96.14     1.0      27.61       8.60        0.209
# 208    2.33   0.00   97.67     2.0      21.84       4.21          NaN
# 209    0.00   0.00  100.00     2.0      22.18       7.11        0.166
# 210   25.88  10.65   63.47     2.0      47.35      12.24        0.311
# 211   56.21   1.61   42.18     3.0       8.82      14.39        0.187
# 212    0.60   2.25   97.15     1.0      18.96       4.40        0.040
# 213   23.46   0.21   76.33     3.0      10.71      10.13        0.005
# 214   19.13   0.22   80.65     3.0      14.14       8.26        0.010
# 215    7.43   0.23   92.34     3.0      13.91       9.05        0.093
# 216   10.83   0.83   88.34     1.0      26.36       7.84        0.342
# 217    2.46   7.38   90.16     2.0      22.72       7.82        0.260
# 218    2.95   0.92   96.13     2.0      18.71       4.92        0.040
# 219   19.97   5.95   74.08     2.0      16.86       6.22        0.209
# 220   11.76   2.94   85.30     2.0      13.96       6.43        0.010
# 221    5.00  25.00   70.00     2.0        NaN        NaN          NaN
# 222   16.90  18.97   64.13     3.0      31.67       3.92        0.090
# 223    0.02   0.00   99.98     1.0        NaN        NaN          NaN
# 224    2.78   0.24   96.98     1.0      42.89       8.30        0.135
# 225    7.08   0.03   92.90     2.0      41.00      19.93        0.220
# 226    8.32   0.34   91.34     2.0      28.01      21.84        0.179
#
#      Industry  Service
# 0       0.240    0.380
# 1       0.188    0.579
# 2       0.600    0.298
# 3         NaN      NaN
# 4         NaN      NaN
# 5       0.658    0.246
# 6       0.180    0.780
# 7       0.220    0.743
# 8       0.358    0.547
# 9       0.343    0.418
# 10      0.333    0.663
# 11      0.262    0.700
# 12      0.304    0.678
# 13      0.457    0.402
# 14      0.070    0.900
# 15      0.387    0.608
# 16      0.198    0.603
# 17      0.160    0.780
# 18      0.316    0.591
# 19      0.240    0.749
# 20      0.152    0.612
# 21      0.138    0.546
# 22      0.100    0.890
# 23      0.379    0.363
# 24      0.352    0.520
# 25      0.308    0.550
# 26      0.469    0.507
# 27      0.400    0.516
# 28      0.062    0.920
# 29      0.561    0.403
# ..        ...      ...
# 197     0.230    0.519
# 198     0.259    0.723
# 199     0.286    0.480
# 200     0.172    0.396
# 201     0.441    0.460
# 202     0.204    0.401
# 203     0.270    0.500
# 204     0.570    0.423
# 205     0.318    0.550
# 206     0.298    0.585
# 207     0.380    0.411
# 208       NaN      NaN
# 209     0.272    0.562
# 210     0.222    0.469
# 211     0.452    0.361
# 212     0.585    0.375
# 213     0.237    0.758
# 214     0.204    0.787
# 215     0.311    0.596
# 216     0.229    0.430
# 217     0.120    0.620
# 218     0.419    0.541
# 219     0.410    0.381
# 220     0.190    0.800
# 221       NaN      NaN
# 222     0.280    0.630
# 223       NaN    0.400
# 224     0.472    0.393
# 225     0.290    0.489
# 226     0.243    0.579
#
# [227 rows x 20 columns]
